# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.interpolate as interpolate

# %%
Version = ['Both', 'ROS2', 'ROS1', 'Not\nspecified']
Quantity = [2, 2, 11, 24]

plt.barh(Version, Quantity, color = 'darkgray', edgecolor = 'black')

for index, value in enumerate(Quantity):
    plt.text(value, index, "  " + str(value))

plt.xlim([0, 30])
#plt.show()
plt.savefig('figures/ros_version.pdf', bbox_inches='tight')

# %%
Type = ['Mobile\naquatic', 'Fixed', 'Multiple', 'Mobile\nairborne', 'Not\nspecified', 'Mobile\nterrastrial']
Quantity = [0, 1, 2, 3, 10, 23]

plt.barh(Type, Quantity, color = 'darkgray', edgecolor = 'black')

for index, value in enumerate(Quantity):
    plt.text(value, index, "  " + str(value))

plt.xlim([0, 25])
#plt.show()
plt.savefig('figures/type_of_robot.pdf', bbox_inches='tight')

# %%
Type = ['Multiple\nrobots', 'Single\nrobot']
Quantity = [7, 24]

plt.barh(Type, Quantity, color = 'darkgray', edgecolor = 'black')

for index, value in enumerate(Quantity):
    plt.text(value, index, "  " + str(value))

plt.xlim([0, 30])
#plt.show()
plt.savefig('figures/cardinality.pdf', bbox_inches='tight')

# %%
Type = ['Philosophical\npaper', 'Evaluation\nresearch', 'Validation\nresearch', 'Proposal of\na solution']
Quantity = [3, 7, 17, 30]

plt.barh(Type, Quantity, color = 'darkgray', edgecolor = 'black')

for index, value in enumerate(Quantity):
    plt.text(value, index, "  " + str(value))

plt.xlim([0, 35])
#plt.show()
plt.savefig('figures/research_strategy.pdf', bbox_inches='tight')

# %%
Type = ['Hybrid\nexperiment', 'Interview', 'Mining software\nrepos', 'Survey', 'Real deployment', 'Lab experiment', 
        'Proof of concept', 'Simulation-based\nexperiment']
Quantity = [1, 2, 3, 3, 4, 8, 10, 10]

plt.barh(Type, Quantity, color = 'darkgray', edgecolor = 'black')

for index, value in enumerate(Quantity):
    plt.text(value, index, "  " + str(value))

plt.xlim([0, 12])
#plt.show()
plt.savefig('figures/research_method.pdf', bbox_inches='tight')

# %%
total_scores = [0, 1, 2, 3, 4]
no_of_studies = [13, 13, 5, 5, 3]

labels = ['Subjects', 'Context', 'Scale', 'Research\nmethod']
score_zero = [18, 26, 30, 32]
score_one = [21, 13, 9, 7]

x = np.arange(len(labels))
width = 0.30  

fig, (ax1, ax2) = plt.subplots(2)

rects = ax1.bar(total_scores, no_of_studies, 0.5, color='darkslategray') 
ax1.set_ylabel('Number of studies')
ax1.set_xlabel('Cumulative industrial score')


rects1 = ax2.bar(x - width/2, score_zero, width, label='0', color='gray')
rects2 = ax2.bar(x + width/2, score_one, width, label='1', color='lightgray')

ax2.set_ylabel('Number of studies')
ax2.set_xticks(x)
ax2.set_xticklabels(labels)
ax2.legend()


def autolabel(rects, ax):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects, ax1)        
autolabel(rects1, ax2)
autolabel(rects2, ax2)

ax1.set_ylim(0, 20)
ax2.set_ylim(0, 40)

fig.tight_layout()

#plt.show()
plt.savefig('figures/industrial_score.pdf', bbox_inches='tight')
