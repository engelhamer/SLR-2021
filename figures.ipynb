# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib_venn import venn3_unweighted, venn3_circles

# %%
types = ['Filesystem', 'Community', 'Computation\ngraph']
subsets = [5, 0, 3, 1, 27, 0, 3]
subset_areas = [10, 0, 3, 5, 27, 0, 3]
set_colors = ['darkblue', 'red', 'yellow', 'white', 'green', 'magenta']

circles = venn3_unweighted(subsets = subsets, subset_areas=subset_areas, set_labels = types, alpha = 00.4, set_colors=set_colors)
venn3_circles(subsets = (10, 0, 3, 5, 27, 0, 3), alpha = 0.5)

ax.legend(custom_lines, ['Cold', 'Medium', 'Hot'])


# plt.show()
plt.savefig('figures/ros_ecosystem_level_circle.pdf')

# %%
labels = [ 'Package', 'Tool', 'Model', 'Method', 'Architecture',]
frequencies = [2, 2, 4, 13, 18]

plt.barh(labels, frequencies, color = 'darkgray', edgecolor = 'black')

for index, value in enumerate(frequencies):
    plt.text(value, index, "  " + str(value))

# https://stackoverflow.com/questions/46795840/matplotlib-float-values-on-the-axis-instead-of-integers
locator = ticker.MultipleLocator(2)
plt.gca().xaxis.set_major_locator(locator)
formatter = ticker.StrMethodFormatter("{x:.0f}")
plt.gca().xaxis.set_major_formatter(formatter)

plt.xlim([0, 20])
#plt.show()
plt.savefig('figures/main_contribution.pdf', bbox_inches='tight')

# %%
labels = ['Other','Edge computing','Code analysis','Machine learning','Code generation','LIDAR','Formal modeling\n/ specification']
frequencies = [12,2,4,4,5,5,9]

plt.barh(labels, frequencies, color = 'darkgray', edgecolor = 'black')

for index, value in enumerate(frequencies):
    plt.text(value, index, "  " + str(value))
    
locator = ticker.MultipleLocator(2)
plt.gca().xaxis.set_major_locator(locator)
formatter = ticker.StrMethodFormatter("{x:.0f}")
plt.gca().xaxis.set_major_formatter(formatter)

plt.xlim([0, 14])
#plt.show()
plt.savefig('figures/interdependent_technologies.pdf', bbox_inches='tight')

# %%
labels = ['Other','Unknown hardware','Kobuki','Turtlebot','SoC','FPGA','No hardware']
frequencies = [14,1,2,4,6,7,15]

plt.barh(labels, frequencies, color = 'darkgray', edgecolor = 'black')

for index, value in enumerate(frequencies):
    plt.text(value, index, "  " + str(value))
    
locator = ticker.MultipleLocator(2)
plt.gca().xaxis.set_major_locator(locator)
formatter = ticker.StrMethodFormatter("{x:.0f}")
plt.gca().xaxis.set_major_formatter(formatter)

plt.xlim([0, 16])
#plt.show()
plt.savefig('figures/hardware_platform.pdf', bbox_inches='tight')

# %%
labels = ['Community', 'Computation graph', 'Filesystem']
frequencies = [3, 31, 38]

plt.barh(labels, frequencies, color = 'darkgray', edgecolor = 'black')

for index, value in enumerate(frequencies):
    plt.text(value, index, "  " + str(value))
    
plt.xlim([0, 40])
#plt.show()
plt.savefig('figures/ecosystem_level.pdf', bbox_inches='tight')

# %%
types = ['Publish-subscribe', 'Services', 'Shared memory']
subsets = [20, 0, 6, 0, 1, 0, 1]

circles = venn3(subsets = subsets, set_labels = types, alpha = 0.5)

# plt.show()
plt.savefig('figures/communication_paradigm.pdf')

# %%
labels = ['Security','Reliability','Functional suitability','Usability','Compatibility','Maintainability','Portability','Performance']
frequencies = [4,9,10,10,13,17,18,19]

plt.barh(labels, frequencies, color = 'darkgray', edgecolor = 'black')

for index, value in enumerate(frequencies):
    plt.text(value, index, "  " + str(value))
    
locator = ticker.MultipleLocator(2)
plt.gca().xaxis.set_major_locator(locator)
formatter = ticker.StrMethodFormatter("{x:.0f}")
plt.gca().xaxis.set_major_formatter(formatter)
    
plt.xlim([0, 21])
#plt.show()
plt.savefig('figures/quality_attributes.pdf', bbox_inches='tight')

# %%
import numpy as np

# create data
rigor = [0, 0, 0.5, 1, 1, 1, 1.5, 1.5, 1.5, 1.5, 2, 2, 2, 2, 2.5, 3, 3, 3, 3]
relevance = [0, 1, 1, 0, 1, 2, 0, 1, 2, 4, 0, 1, 2, 3, 3, 1, 2, 3, 4]
frequencies = np.array([2, 1, 1, 7, 5, 2, 3, 3, 1, 2, 1, 1, 1, 2, 1, 2, 1, 2, 1])
 
# Change color with c and alpha
plt.scatter(relevance, rigor, s=frequencies*200, c="red", edgecolor="black")

for relevance_val, rigor_val, frequency_val in zip(relevance, rigor, frequencies):
    plt.text(relevance_val - 0.05, rigor_val - 0.03, frequency_val)

locator = ticker.MultipleLocator(1)
plt.gca().xaxis.set_major_locator(locator)
formatter = ticker.StrMethodFormatter("{x:.0f}")
plt.gca().xaxis.set_major_formatter(formatter)

plt.xlim([-0.5, 4.5])
plt.ylabel('Rigor')
plt.xlabel('Industrial relevance')
#plt.show()
plt.savefig('figures/rigor_relevance.pdf', bbox_inches='tight')
